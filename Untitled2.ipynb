# %% [markdown]
# <a href="https://colab.research.google.com/github/Udit-Agarwal20/Python-class-codes/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as at


#create a dictionary
dct = {
    'name' : ['Tom','Nick','Krish','Jack'],
    'age': [20,768,90,32],
    'roll': [1,2,3,4]
}

df = ut.DataFrame(dct)
display(df)

# %%
xy = ut.read_csv('student_data.csv')

# head gave first 5 values and if we wrute inside its brackets that that much lines it will print

display(xy.head())
xy.tail()

# %%
# it tells us How many rows and columns does my table have?

display(xy.shape)

# %%
#metadata is a data about data.

xy.info()

# %%
# on the horizontal bar there is column names then cout shows how many values in that column. std is standard deviation.

# 25% -> first quortile and 25%
# 50% -> second quortile and 50%
# 75% -> third quortile and 75%

xy.describe()

# %%
# print the column named internet usage if we want to print multiple columns then we will gave it in list
display(xy[['study_hours','internet_usage']])
xy['internet_usage']

# %%
#to access individual rows inside that we will write index number

display(xy.iloc[[7,0,9]]) # for multiple rows
xy.iloc[79] # for single row

# %%
# it will print all the data rows in which attendence is equal 100 then in second line we write another data column name which will print that perticular column data for which attendence is 100 and lastly iloc tells print only from index 4 to 8.


display(xy.loc[xy['attendance']==100])


xy.loc[xy['attendance']==100, ['sleep_hours']].iloc[4:8]

# %% [markdown]
# ### Practice Exercises
#
# **1. Easy Task:** Display the `exam_score` and `placement_status` for the first 10 rows of the `xy` dataset.
#
# **2. Medium Task:** Filter the `xy` dataset for students with `attendance > 90` and `study_hours > 8`. From this filtered list, use `.loc` or `.iloc` to show only the `exam_score` and `internet_usage` for results starting from index 10 to 20.

# %%
# Write your solution for Task 1 here

# %%
# Write your solution for Task 2 here

# %%
#iloc works on its own indexingf that it will form by itself but loc is not works like that it will work on the label that is given in data

# %%
xy.loc[9]

# %%
#question

xy.loc[xy['assignments_completed']== 8,['assignments_completed'] ].iloc[1]

# %%
#print all rows for which the value of assignments_completed is greater than 18 this is the filtering of data

xy[xy['assignments_completed']>18]

# %%
# used to add new data

xy["relationship_status"]="single"
xy

# %%
xy["relationship_status"] == "single" if xy[xy['sleep_hours']>7] else xy["relationship_status"] == "mingle"

# %%
# rename column. it returns a new dataframe

xy.rename(columns={'sleep_hours':'battery_charge'},inplace=True)
xy

# %%
#to remove the data or to remove the whole column

xy = xy.drop('attendance',axis=1)
display(xy)

#to remove the data or to remove the perticular row
xy = xy.drop(5,axis=0)
